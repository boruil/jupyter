# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# %%
df = pd.read_csv('train.csv')[:1000]
df.head()
# Out:
#    custid  retained   created firstorder lastorder  esent   eopenrate  \
# 0  6H6T6N         0   9/27/08    8/10/09   8/10/09     29  100.000000
# 1  APCENR         1  12/18/06    3/31/07   1/18/10     95   92.631579
# 2  7UP6MS         0   10/2/06   11/30/06    7/5/07      0    0.000000
# 3  7ZEW8G         0  10/21/06    3/27/07   3/27/07      0    0.000000
# 4  8V726M         1  11/26/06   11/28/06   1/27/09     30   90.000000
#
#    eclickrate  avgorder   ordfreq  paperless  refill  doorstep  train  \
# 0    3.448276     14.52  0.000000          0       0         0      1
# 1   10.526316     83.69  0.181641          1       1         1      1
# 2    0.000000     33.58  0.059908          0       0         0      1
# 3    0.000000     54.96  0.000000          0       0         0      1
# 4   13.333333    111.91  0.008850          0       0         0      1
#
#       favday city
# 0     Monday  CHO
# 1     Friday  CHO
# 2  Wednesday  CHO
# 3   Thursday  RIC
# 4     Monday  RIC

# %%
df['orderdate'] = 0

for i in range(len(df)):
    y = df['firstorder'][i].split('/')
    year = y[2]
    if str(year) != '09':
        df.drop(df.index[i])

# %%
df
# Out:
#      custid  retained   created firstorder lastorder  esent   eopenrate  \
# 0    6H6T6N         0   9/27/08    8/10/09   8/10/09     29  100.000000
# 1    APCENR         1  12/18/06    3/31/07   1/18/10     95   92.631579
# 2    7UP6MS         0   10/2/06   11/30/06    7/5/07      0    0.000000
# 3    7ZEW8G         0  10/21/06    3/27/07   3/27/07      0    0.000000
# 4    8V726M         1  11/26/06   11/28/06   1/27/09     30   90.000000
# 5    2B6B83         1  11/16/04   10/11/06   1/13/10     46   80.434783
# 6    99XGVM         1   1/23/07    5/15/07   1/15/10     60   43.333333
# 7    U3MP5L         1   12/3/05    9/20/07   1/15/10     64   28.125000
# 8    ELKAGQ         1   9/17/06    11/8/06   11/8/06     45    0.000000
# 9    3SBQP2         1  12/28/06    2/19/07   12/9/09     34   94.117647
# 10   YMALVV         1   9/21/06   11/17/06   1/14/10     48   83.333333
# 11   GW8NT7         1  11/15/05     5/8/07    1/4/10     40   87.500000
# ...
